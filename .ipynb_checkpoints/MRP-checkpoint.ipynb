# %% [markdown]
# # Multi-level Regression with Postratification

# %%
import pandas as pd
import os

# %%
wd = os.getcwd()

# %%
dss = f'{wd}/Data'

# %%
demog = pd.read_csv(f'{dss}/ONS_demographics.csv')

# %%
demog
# Out:
#       Post-2019 Westminster Parliamentary constituencies Code  \
# 0                                              E14001063
# 1                                              E14001063
# 2                                              E14001063
# 3                                              E14001063
# 4                                              E14001063
# ...                                                  ...
# 48295                                          W07000112
# 48296                                          W07000112
# 48297                                          W07000112
# 48298                                          W07000112
# 48299                                          W07000112
#
#       Post-2019 Westminster Parliamentary constituencies  \
# 0                                              Aldershot
# 1                                              Aldershot
# 2                                              Aldershot
# ...
